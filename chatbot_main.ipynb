# %%
from langgraph.graph import StateGraph, START, END
from langchain_core.messages import BaseMessage, HumanMessage
from typing import TypedDict, Annotated
from langchain_groq import ChatGroq
from langgraph.graph.message import add_messages
from dotenv import load_dotenv

# %%
class ChatState(TypedDict):
    # BaseMessage means any tpe of message can exit in this list like it could be human, AI,system message
    # addmessages work same as operator.add but it is more optimized with baseMessage
    messages: Annotated[list[BaseMessage], add_messages]

# %%
load_dotenv()
llm = ChatGroq(model="openai/gpt-oss-120b")
def chat_node(state: ChatState):

    # take user input
    messages = state['messages']

    # send to llm
    response = llm.invoke(messages)

    # return state
    return {'messages': [response]}
# Out:
# ---------------------------------------------------------------------------
# GroqError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 llm = ChatGroq(model="openai/gpt-oss-120b")
#       2 def chat_node(state: ChatState):
#       3
#       4     # take user input
#
# File ~\Desktop\uni\llm_chatbot\Chatbot\chatbot_env\Lib\site-packages\langchain_core\load\serializable.py:136, in Serializable.__init__(self, *args, **kwargs)
#     134 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     135     """"""  # noqa: D419  # Intentional blank docstring
# --> 136     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~\Desktop\uni\llm_chatbot\Chatbot\chatbot_env\Lib\site-packages\langchain_groq\chat_models.py:530, in ChatGroq.validate_environment(self)
#     528 sync_specific: dict[str, Any] = {"http_client": self.http_client}
#     529 if not self.client:
# --> 530     self.client = groq.Groq(
#     531         **client_params, **sync_specific
#     532     ).chat.completions
#     533 if not self.async_client:
#     534     async_specific: dict[str, Any] = {"http_client": self.http_async_client}
#
# File ~\Desktop\uni\llm_chatbot\Chatbot\chatbot_env\Lib\site-packages\groq\_client.py:79, in Groq.__init__(self, api_key, base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#      77     api_key = os.environ.get("GROQ_API_KEY")
#      78 if api_key is None:
# ---> 79     raise GroqError(
#      80         "The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable"
#      81     )
#      82 self.api_key = api_key
#      84 if base_url is None:
#
# GroqError: The api_key client option must be set either by passing api_key to the client or by setting the GROQ_API_KEY environment variable

# %%
graph = StateGraph(ChatState)

graph.add_node('chat_node', chat_node)

graph.add_edge(START, 'chat_node')
graph.add_edge('chat_node', END)

graph.compile()
